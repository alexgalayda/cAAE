# %%
import ants

# %%
img = ants.image_read( ants.get_ants_data('r16') )

# %%
ants.plot(img)

# %%
img.shape
# Out:
# (256, 256)

# %%
print(img.spacing)
img.set_spacing( (2., 2.) )
# Out:
# (1.0, 1.0)

# %%
print(img.origin)
# Out:
# (0.0, 0.0)

# %%
img.set_origin( (100,100) )

# %%
ants.get_spacing(img)
# Out:
# (2.0, 2.0)

# %%
img_array = img.numpy()

# %%
img_array.shape
# Out:
# (256, 256)

# %%
img = ants.image_read( ants.get_ants_data('mni') )
img_array = img.numpy()
img_array.shape
# Out:
# (182, 218, 182)

# %%
ants.plot(img)

# %%
new_img1 = img.new_image_like(img_array)

# doesnt copy any information
new_img2 = ants.from_numpy(img_array)

# verbose way to copy information
new_img3 = ants.from_numpy(img_array, spacing=img.spacing,
                           origin=img.origin, direction=img.direction)

# %%
new_img3
# Out:
# ANTsImage (RPI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (182, 218, 182)
# 	 Spacing    : (1.0, 1.0, 1.0)
# 	 Origin     : (-90.0, 126.0, -72.0)
# 	 Direction  : [ 1.  0.  0.  0. -1.  0.  0.  0.  1.]

# %%
img.resample_image((64,64), 1, 0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-dec298039cd1> in <module>
# ----> 1 img.resample_image((64,64), 1, 0)
#
# /opt/conda/lib/python3.6/site-packages/ants/registration/resample_image.py in resample_image(image, resample_params, use_voxels, interp_type)
#      50         processed_args = utils._int_antsProcessArguments(args)
#      51         libfn = utils.get_lib_fn('ResampleImage')
# ---> 52         libfn(processed_args)
#      53         outimage = outimage.clone(image.pixeltype)
#      54         return outimage
#
# RuntimeError: /root/ANTsPy/itksource/Modules/Core/Common/include/itkImportImageContainer.hxx:192:
# Failed to allocate memory for image.

# %%
img = ants.image_read(ants.get_ants_data('r16'))
ants.plot(img)

# %%
img1 = img.resample_image((64,64), 1, 0)
ants.plot(img1)

# %%
pp = '/root/HCP/T2w_restore_brain/T2w_restore_brain_115724.nii.gz'

# %%
ll = ants.image_read(pp)

# %%
ants.plot(ll)

# %%
ll.shape
# Out:
# (260, 311, 260)

# %%
lll = ll.resample_image((64, 311, 64), 1, 0)
ants.plot(lll)

# %%
from intensity_normalization.normalize.zscore import zscore_normalize
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
zscore_normalize(ll)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-a7c459003714> in <module>
# ----> 1 zscore_normalize(ll)
#
# /opt/conda/lib/python3.6/site-packages/intensity_normalization-1.4.1-py3.6.egg/intensity_normalization/normalize/zscore.py in zscore_normalize(img, mask)
#      34     """
#      35
# ---> 36     img_data = img.get_data()
#      37     if mask is not None and not isinstance(mask, str):
#      38         mask_data = mask.get_data()
#
# AttributeError: 'ANTsImage' object has no attribute 'get_data'

# %%
ants.reorient_image(image, (1,0))

# %%
img.shape
# Out:
# (256, 256)

# %%
kk = ll[0]
kk.shape
# Out:
# (311, 260)

# %%
ants.iMath_normalize(ll).min()
# Out:
# 0.0

# %%
ants.plot(ants.iMath(ll, "Normalize"))
